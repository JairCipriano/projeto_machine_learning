# %%
import matplotlib as plt
import numpy as np
import pandas as pd

# %%
df2 = pd.DataFrame([22, 44, 55], ['arroz', 'feijão', 'batata'], ['quantidade'])
df2
# Out:
#         quantidade
# arroz           22
# feijão          44
# batata          55

# %%
np.random.randint(20, size=(3,3))
# Out:
# array([[ 4, 18, 14],
#        [14,  1,  2],
#        [19,  9, 19]], dtype=int32)

# %%
carros = pd.DataFrame(
    np.random.randint(3000, 25000, size=(8, 12)),  # Ajustando os limites para que o primeiro seja menor que o segundo
    index=['fiat', 'peugeot', 'volkswagen', 'ford', 'nissan', 'toyota', 'honda', 'chevrolet'],  # Corrigindo o nome 'pegeot' para 'peugeot' e 'volkswagem' para 'volkswagen'
    columns=['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']  # Corrigindo 'des' para 'dez'
)
carros
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat         5245   6776  12633   9392  24470   3084  13621  22828  20147
# peugeot     23611  13598  18765  11991   3774  24480  16082  22743  12769
# volkswagen  11355  24707  19804  16551  10774   8007  21191  19159  23513
# ford         4293   6018   6538  13952  18106   8615  21261   9032  18332
# nissan      18265  12858  23387  19954  24645  11374  12871  18931  17493
# toyota       4481  15878  10893  14553   6055  16183  18843   3056  13827
# honda       19253  23130  19578  14423  24046   3270  14172   3360  24695
# chevrolet    7228   7174   8563  11901  14502  11483  20293  21839   7221
#
#               out    nov    dez
# fiat        23979   5752  20387
# peugeot      7493   4912  17802
# volkswagen  11752  18546  16160
# ford        23548  24524   4700
# nissan      13031  21925  21438
# toyota      18813   5201   3477
# honda       23548  24977   7234
# chevrolet   10797   9536   7857

# %%
carros['total'] = carros.sum(axis=1)
carros
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat         5245   6776  12633   9392  24470   3084  13621  22828  20147
# peugeot     23611  13598  18765  11991   3774  24480  16082  22743  12769
# volkswagen  11355  24707  19804  16551  10774   8007  21191  19159  23513
# ford         4293   6018   6538  13952  18106   8615  21261   9032  18332
# nissan      18265  12858  23387  19954  24645  11374  12871  18931  17493
# toyota       4481  15878  10893  14553   6055  16183  18843   3056  13827
# honda       19253  23130  19578  14423  24046   3270  14172   3360  24695
# chevrolet    7228   7174   8563  11901  14502  11483  20293  21839   7221
#
#               out    nov    dez   total
# fiat        23979   5752  20387  168314
# peugeot      7493   4912  17802  178020
# volkswagen  11752  18546  16160  201519
# ford        23548  24524   4700  158919
# nissan      13031  21925  21438  216172
# toyota      18813   5201   3477  131260
# ...

# %%
carros['origem'] = ['italia', 'frança', 'alemanha','eua', 'japão', 'japão','japão', 'eua' ]

# %%
carros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, fiat to chevrolet
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   jan     8 non-null      int32
#  1   fev     8 non-null      int32
#  2   mar     8 non-null      int32
#  3   abr     8 non-null      int32
#  4   mai     8 non-null      int32
#  5   jun     8 non-null      int32
#  6   jul     8 non-null      int32
#  7   ago     8 non-null      int32
#  8   set     8 non-null      int32
#  9   out     8 non-null      int32
#  10  nov     8 non-null      int32
#  11  dez     8 non-null      int32
#  12  total   8 non-null      int64
#  13  origem  8 non-null      object
# dtypes: int32(12), int64(1), object(1)
# memory usage: 576.0+ bytes

# %%
carros.describe()
# Out:
#                 jan           fev           mar           abr           mai  \
# count      8.000000      8.000000      8.000000      8.000000      8.000000
# mean   11716.375000  13767.375000  15020.125000  14089.625000  15796.500000
# std     7660.466732   7221.488389   6141.902973   3208.382856   8394.319167
# min     4293.000000   6018.000000   6538.000000   9392.000000   3774.000000
# 25%     5054.000000   7074.500000  10310.500000  11968.500000   9594.250000
# 50%     9291.500000  13228.000000  15699.000000  14187.500000  16304.000000
# 75%    18512.000000  17691.000000  19634.500000  15052.500000  24152.000000
# max    23611.000000  24707.000000  23387.000000  19954.000000  24645.000000
#
#                 jun           jul           ago           set           out  \
# count      8.000000      8.000000      8.000000      8.000000      8.000000
# mean   10812.000000  17291.750000  15118.500000  17249.625000  16620.125000
# ...

# %%
carros.columns
# Out:
# Index(['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out',
#        'nov', 'dez', 'total', 'origem'],
#       dtype='object')

# %%
carros [['jan', 'abr' , 'origem']]
# Out:
#               jan    abr    origem
# fiat         5245   9392    italia
# peugeot     23611  11991    frança
# volkswagen  11355  16551  alemanha
# ford         4293  13952       eua
# nissan      18265  19954     japão
# toyota       4481  14553     japão
# honda       19253  14423     japão
# chevrolet    7228  11901       eua

# %%
carros.index
# Out:
# Index(['fiat', 'peugeot', 'volkswagen', 'ford', 'nissan', 'toyota', 'honda',
#        'chevrolet'],
#       dtype='object')

# %%
carros.sort_values (by='total')
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# toyota       4481  15878  10893  14553   6055  16183  18843   3056  13827
# chevrolet    7228   7174   8563  11901  14502  11483  20293  21839   7221
# ford         4293   6018   6538  13952  18106   8615  21261   9032  18332
# fiat         5245   6776  12633   9392  24470   3084  13621  22828  20147
# peugeot     23611  13598  18765  11991   3774  24480  16082  22743  12769
# volkswagen  11355  24707  19804  16551  10774   8007  21191  19159  23513
# honda       19253  23130  19578  14423  24046   3270  14172   3360  24695
# nissan      18265  12858  23387  19954  24645  11374  12871  18931  17493
#
#               out    nov    dez   total    origem
# toyota      18813   5201   3477  131260     japão
# chevrolet   10797   9536   7857  138394       eua
# ford        23548  24524   4700  158919       eua
# fiat        23979   5752  20387  168314    italia
# ...

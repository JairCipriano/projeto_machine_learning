# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

# %%
import yfinance as yf
import datetime

# %%
# %matplotlib inline

# %%
biticoin = yf.download('BTC-USD',
                              start = datetime.datetime(2018,1,1),
                              end = datetime.datetime(2022,4,1))
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
biticoin
# Out:
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2018-01-01  13657.200195  14112.200195  13154.700195  14112.200195
# 2018-01-02  14982.099609  15444.599609  13163.599609  13625.000000
# 2018-01-03  15201.000000  15572.799805  14844.500000  14978.200195
# 2018-01-04  15599.200195  15739.700195  14522.200195  15270.700195
# 2018-01-05  17429.500000  17705.199219  15202.799805  15477.200195
# ...                  ...           ...           ...           ...
# 2022-03-27  46820.492188  46827.546875  44437.292969  44505.355469
# 2022-03-28  47128.003906  48086.835938  46690.203125  46821.851562
# 2022-03-29  47465.730469  48022.289062  47100.437500  47100.437500
# 2022-03-30  47062.664062  47655.148438  46746.210938  47456.898438
# 2022-03-31  45538.675781  47512.027344  45390.539062  47062.148438
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2018-01-01  10291200000
# ...

# %%
biticoin['Close'].plot(figsize=(16,10))
# Out:
# <Axes: xlabel='Date'>

# %%
btc = biticoin.loc['2021-01': '2022-04'].copy()
btc
# Out:
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2021-01-01  29374.152344  29600.626953  28803.585938  28994.009766
# 2021-01-02  32127.267578  33155.117188  29091.181641  29376.455078
# 2021-01-03  32782.023438  34608.558594  32052.316406  32129.408203
# 2021-01-04  31971.914062  33440.218750  28722.755859  32810.949219
# 2021-01-05  33992.429688  34437.589844  30221.187500  31977.041016
# ...                  ...           ...           ...           ...
# 2022-03-27  46820.492188  46827.546875  44437.292969  44505.355469
# 2022-03-28  47128.003906  48086.835938  46690.203125  46821.851562
# 2022-03-29  47465.730469  48022.289062  47100.437500  47100.437500
# 2022-03-30  47062.664062  47655.148438  46746.210938  47456.898438
# 2022-03-31  45538.675781  47512.027344  45390.539062  47062.148438
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2021-01-01  40730301359
# ...

# %%
btc['MMS30'] = btc['Close'].rolling(window= 30).mean()

# %%
btc.head(31)
# Out:
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2021-01-01  29374.152344  29600.626953  28803.585938  28994.009766
# 2021-01-02  32127.267578  33155.117188  29091.181641  29376.455078
# 2021-01-03  32782.023438  34608.558594  32052.316406  32129.408203
# 2021-01-04  31971.914062  33440.218750  28722.755859  32810.949219
# 2021-01-05  33992.429688  34437.589844  30221.187500  31977.041016
# 2021-01-06  36824.363281  36879.699219  33514.035156  34013.613281
# 2021-01-07  39371.042969  40180.367188  36491.191406  36833.875000
# 2021-01-08  40797.609375  41946.738281  36838.636719  39381.765625
# 2021-01-09  40254.546875  41436.351562  38980.875000  40788.640625
# 2021-01-10  38356.441406  41420.191406  35984.628906  40254.218750
# 2021-01-11  35566.656250  38346.531250  30549.599609  38346.531250
# 2021-01-12  33922.960938  36568.527344  32697.976562  35516.359375
# ...

# %%
fig, ax = plt.subplots(figsize = (14,8))
ax.plot(btc['Close'],label = 'biticoin')
ax.plot(btc['MMS30'],label = 'MMS 30')
ax.plot(btc['Close'].rolling(window =  15).mean(),label = 'MMS 15')
#.rolling - referente ao fechamento
#window é o periodo de tempo que você quer
#.mean() é a media
#label é o nome que você quer chamar extamente aquelka linha do grafico

plt.legend()
#ple.legend é usado para adicionar a caixinha da legenda
plt.show()
#plt.show é uxado para impremir o grafico na tela

# %%
btc['MME30'] = btc['Close'].ewm(span= 30).mean()
#ewm é a mesma coisa do rolling só que para exponecial
#span mesma coisa que window só que para exponecial

# %%
btc.head(31)
# Out:
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2021-01-01  29374.152344  29600.626953  28803.585938  28994.009766
# 2021-01-02  32127.267578  33155.117188  29091.181641  29376.455078
# 2021-01-03  32782.023438  34608.558594  32052.316406  32129.408203
# 2021-01-04  31971.914062  33440.218750  28722.755859  32810.949219
# 2021-01-05  33992.429688  34437.589844  30221.187500  31977.041016
# 2021-01-06  36824.363281  36879.699219  33514.035156  34013.613281
# 2021-01-07  39371.042969  40180.367188  36491.191406  36833.875000
# 2021-01-08  40797.609375  41946.738281  36838.636719  39381.765625
# 2021-01-09  40254.546875  41436.351562  38980.875000  40788.640625
# 2021-01-10  38356.441406  41420.191406  35984.628906  40254.218750
# 2021-01-11  35566.656250  38346.531250  30549.599609  38346.531250
# 2021-01-12  33922.960938  36568.527344  32697.976562  35516.359375
# ...

# %%
fig, ax = plt.subplots(figsize = (14,8))
ax.plot(btc['Close'],label = 'biticoin')
ax.plot(btc['MMS30'],label = 'MMS 30')
ax.plot(btc['MME30'].ewm(span =  15).mean(),label = 'MME 15')


plt.legend()

plt.show()

# %%
btc
# Out:
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2021-01-01  29374.152344  29600.626953  28803.585938  28994.009766
# 2021-01-02  32127.267578  33155.117188  29091.181641  29376.455078
# 2021-01-03  32782.023438  34608.558594  32052.316406  32129.408203
# 2021-01-04  31971.914062  33440.218750  28722.755859  32810.949219
# 2021-01-05  33992.429688  34437.589844  30221.187500  31977.041016
# ...                  ...           ...           ...           ...
# 2022-03-27  46820.492188  46827.546875  44437.292969  44505.355469
# 2022-03-28  47128.003906  48086.835938  46690.203125  46821.851562
# 2022-03-29  47465.730469  48022.289062  47100.437500  47100.437500
# 2022-03-30  47062.664062  47655.148438  46746.210938  47456.898438
# 2022-03-31  45538.675781  47512.027344  45390.539062  47062.148438
#
# Price            Volume         MMS30         MME30
# Ticker          BTC-USD
# Date
# ...

# %%
btc[['Close', 'MMS30', 'MME30']].plot(figsize=(16,8))
# Out:
# <Axes: xlabel='Date'>

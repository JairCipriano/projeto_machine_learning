# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df2 = pd.DataFrame([22, 44, 55], ['arroz', 'feijão', 'batata'], ['quantidade'])
df2
# Out:
#         quantidade
# arroz           22
# feijão          44
# batata          55

# %%
np.random.randint(20, size=(3,3))
# Out:
# array([[ 2,  0,  5],
#        [14, 16, 11],
#        [18,  6,  7]], dtype=int32)

# %%
carros = pd.DataFrame(
    np.random.randint(3000, 25000, size=(8, 12)),  # Ajustando os limites para que o primeiro seja menor que o segundo
    index=['fiat', 'peugeot', 'volkswagen', 'ford', 'nissan', 'toyota', 'honda', 'chevrolet'],  # Corrigindo o nome 'pegeot' para 'peugeot' e 'volkswagem' para 'volkswagen'
    columns=['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']  # Corrigindo 'des' para 'dez'
)
carros
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#               out    nov    dez
# fiat        15596  14827  16256
# peugeot     15591   8886  22601
# volkswagen   8967  10479  13487
# ford        12620  21972   9259
# nissan      11086  15398  13537
# toyota      19099   9553  20844
# honda       23813  18071   9164
# chevrolet    5021  17621  10304

# %%
carros['total'] = carros.sum(axis=1)
carros
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#               out    nov    dez   total
# fiat        15596  14827  16256  170439
# peugeot     15591   8886  22601  184436
# volkswagen   8967  10479  13487  159800
# ford        12620  21972   9259  164502
# nissan      11086  15398  13537  147646
# toyota      19099   9553  20844  167169
# ...

# %%
carros['origem'] = ['italia', 'frança', 'alemanha','eua', 'japão', 'japão','japão', 'eua' ]

# %%
carros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, fiat to chevrolet
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   jan     8 non-null      int32
#  1   fev     8 non-null      int32
#  2   mar     8 non-null      int32
#  3   abr     8 non-null      int32
#  4   mai     8 non-null      int32
#  5   jun     8 non-null      int32
#  6   jul     8 non-null      int32
#  7   ago     8 non-null      int32
#  8   set     8 non-null      int32
#  9   out     8 non-null      int32
#  10  nov     8 non-null      int32
#  11  dez     8 non-null      int32
#  12  total   8 non-null      int64
#  13  origem  8 non-null      object
# dtypes: int32(12), int64(1), object(1)
# memory usage: 576.0+ bytes

# %%
carros.describe()
# Out:
#                 jan           fev           mar          abr           mai  \
# count      8.000000      8.000000      8.000000      8.00000      8.000000
# mean   10760.375000  10574.375000  14392.250000  12219.25000  15210.125000
# std     4800.159936   4009.939221   6321.038449   6911.20634   8281.449915
# min     4695.000000   5245.000000   7257.000000   3466.00000   3456.000000
# 25%     6925.000000   7881.000000   8025.500000   6044.50000   7533.000000
# 50%    10817.000000  10429.000000  15408.500000  12098.00000  19307.500000
# 75%    14299.000000  13799.500000  17998.000000  18049.50000  21367.750000
# max    17754.000000  16442.000000  24098.000000  21530.00000  23357.000000
#
#                 jun           jul           ago          set           out  \
# count      8.000000      8.000000      8.000000      8.00000      8.000000
# mean   17627.375000  12294.875000  13061.875000  16222.62500  13974.125000
# ...

# %%
carros.columns
# Out:
# Index(['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out',
#        'nov', 'dez', 'total', 'origem'],
#       dtype='object')

# %%
carros [['jan', 'abr' , 'origem']]
# Out:
#               jan    abr    origem
# fiat        17754  19725    italia
# peugeot     13286   6416    frança
# volkswagen   7285  21530  alemanha
# ford         8348  17491       eua
# nissan       4695   4930     japão
# toyota       5845   3466     japão
# honda       14163  12293     japão
# chevrolet   14707  11903       eua

# %%
carros.index
# Out:
# Index(['fiat', 'peugeot', 'volkswagen', 'ford', 'nissan', 'toyota', 'honda',
#        'chevrolet'],
#       dtype='object')

# %%
#ao usar a função  sort_values a organizaão fica em ordem crescente
#Vamos organizar pela coluna total
carros.sort_values (by='total')
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
#
#               out    nov    dez   total    origem
# chevrolet    5021  17621  10304  139894       eua
# nissan      11086  15398  13537  147646     japão
# volkswagen   8967  10479  13487  159800  alemanha
# ford        12620  21972   9259  164502       eua
# ...

# %%
#ao usar a função asacending=False , o programa irá ordenar em ordem decrescente
#usando a coluna total vamos usar a função head para pegar os 5 primeiros 

carros.sort_values(by='total', ascending=False).head()
# Out:
#            jan    fev    mar    abr    mai    jun    jul    ago    set    out  \
# honda    14163  16442  17081  12293   8499   5905  20892  19064  23684  23813
# peugeot  13286  13721  17330   6416  23357  24485   6026  17324  15413  15591
# fiat     17754  10392   7257  19725  21176  23676   8682   6025   9073  15596
# toyota    5845   5679  24098   3466   3456  24441  16298   9813  24577  19099
# ford      8348   5245  13736  17491  21943   6510  23361   9703  14314  12620
#
#            nov    dez   total  origem
# honda    18071   9164  189071   japão
# peugeot   8886  22601  184436  frança
# fiat     14827  16256  170439  italia
# toyota    9553  20844  167169   japão
# ford     21972   9259  164502     eua

# %%
#função tail mostra os ultimas do seu dataframe
carros.sort_values(by='total', ascending=False).tail()
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#               out    nov    dez   total    origem
# toyota      19099   9553  20844  167169     japão
# ford        12620  21972   9259  164502       eua
# volkswagen   8967  10479  13487  159800  alemanha
# nissan      11086  15398  13537  147646     japão
# chevrolet    5021  17621  10304  139894       eua

# %%
#função olha as linhas
carros.drop('ford')
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#               out    nov    dez   total    origem
# fiat        15596  14827  16256  170439    italia
# peugeot     15591   8886  22601  184436    frança
# volkswagen   8967  10479  13487  159800  alemanha
# nissan      11086  15398  13537  147646     japão
# toyota      19099   9553  20844  167169     japão
# honda       23813  18071   9164  189071     japão
# ...

# %%
#usado para mais de 1 linha
carros_alternativo = carros.drop(['ford','honda'])

# %%
carros_alternativo
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#               out    nov    dez   total    origem
# fiat        15596  14827  16256  170439    italia
# peugeot     15591   8886  22601  184436    frança
# volkswagen   8967  10479  13487  159800  alemanha
# nissan      11086  15398  13537  147646     japão
# toyota      19099   9553  20844  167169     japão
# chevrolet    5021  17621  10304  139894       eua

# %%
#usado para dropar colunas
carros.drop('dez', axis=1) 
#se usar o implace=Tru fixa permanete no dataframe
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#               out    nov   total    origem
# fiat        15596  14827  170439    italia
# peugeot     15591   8886  184436    frança
# volkswagen   8967  10479  159800  alemanha
# ford        12620  21972  164502       eua
# nissan      11086  15398  147646     japão
# ...

# %%
carros
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#               out    nov    dez   total    origem
# fiat        15596  14827  16256  170439    italia
# peugeot     15591   8886  22601  184436    frança
# volkswagen   8967  10479  13487  159800  alemanha
# ford        12620  21972   9259  164502       eua
# ...

# %%
carros['origem'].unique()
# Out:
# array(['italia', 'frança', 'alemanha', 'eua', 'japão'], dtype=object)

# %%
carros['origem'].nunique()
# Out:
# 5

# %%
#saber quatas vezes apareceu determinada coisa
carros['origem'].value_counts()
# Out:
# origem
# japão       3
# eua         2
# italia      1
# alemanha    1
# frança      1
# Name: count, dtype: int64

# %%
carros.loc['ford']
# Out:
# jan         8348
# fev         5245
# mar        13736
# abr        17491
# mai        21943
# jun         6510
# jul        23361
# ago         9703
# set        14314
# out        12620
# nov        21972
# dez         9259
# total     164502
# origem       eua
# Name: ford, dtype: object

# %%
#caso queira em um formato de dataframe faa isso
carros.loc[['ford']]
# Out:
#        jan   fev    mar    abr    mai   jun    jul   ago    set    out    nov  \
# ford  8348  5245  13736  17491  21943  6510  23361  9703  14314  12620  21972
#
#        dez   total origem
# ford  9259  164502    eua

# %%
carros.loc[['ford','fiat', 'honda']]
# Out:
#          jan    fev    mar    abr    mai    jun    jul    ago    set    out  \
# ford    8348   5245  13736  17491  21943   6510  23361   9703  14314  12620
# fiat   17754  10392   7257  19725  21176  23676   8682   6025   9073  15596
# honda  14163  16442  17081  12293   8499   5905  20892  19064  23684  23813
#
#          nov    dez   total  origem
# ford   21972   9259  164502     eua
# fiat   14827  16256  170439  italia
# honda  18071   9164  189071   japão

# %%
carros.loc[['ford','fiat', 'honda'], ['total', 'origem']]
# Out:
#         total  origem
# ford   164502     eua
# fiat   170439  italia
# honda  189071   japão

# %%
carros.iloc[3]
# Out:
# jan         8348
# fev         5245
# mar        13736
# abr        17491
# mai        21943
# jun         6510
# jul        23361
# ago         9703
# set        14314
# out        12620
# nov        21972
# dez         9259
# total     164502
# origem       eua
# Name: ford, dtype: object

# %%
#aqui puxa o 0 ao 3
carros.iloc[0:3]
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
#
#               out    nov    dez   total    origem
# fiat        15596  14827  16256  170439    italia
# peugeot     15591   8886  22601  184436    frança
# volkswagen   8967  10479  13487  159800  alemanha

# %%
#aqui puxa o zero eo 3
carros.iloc[[0,3]]
# Out:
#         jan    fev    mar    abr    mai    jun    jul   ago    set    out  \
# fiat  17754  10392   7257  19725  21176  23676   8682  6025   9073  15596
# ford   8348   5245  13736  17491  21943   6510  23361  9703  14314  12620
#
#         nov    dez   total  origem
# fiat  14827  16256  170439  italia
# ford  21972   9259  164502     eua

# %%
#n funcional pois nem todas as colunas são numericas
'''novo_df = carros[carros<900]
novo_df'''
# Out:
# 'novo_df = carros[carros<900]\nnovo_df'

# %%
#usei o info para saber qual n é numerica
carros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, fiat to chevrolet
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   jan     8 non-null      int32
#  1   fev     8 non-null      int32
#  2   mar     8 non-null      int32
#  3   abr     8 non-null      int32
#  4   mai     8 non-null      int32
#  5   jun     8 non-null      int32
#  6   jul     8 non-null      int32
#  7   ago     8 non-null      int32
#  8   set     8 non-null      int32
#  9   out     8 non-null      int32
#  10  nov     8 non-null      int32
#  11  dez     8 non-null      int32
#  12  total   8 non-null      int64
#  13  origem  8 non-null      object
# dtypes: int32(12), int64(1), object(1)
# memory usage: 876.0+ bytes

# %%
#usei o coluns para saber qual as colunas e copias só as numericas
carros.columns
# Out:
# Index(['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out',
#        'nov', 'dez', 'total', 'origem'],
#       dtype='object')

# %%
#apos copiar as numericas
carros2 = carros[['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out',
       'nov', 'dez', 'total']]
carros2
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#               out    nov    dez   total
# fiat        15596  14827  16256  170439
# peugeot     15591   8886  22601  184436
# volkswagen   8967  10479  13487  159800
# ford        12620  21972   9259  164502
# nissan      11086  15398  13537  147646
# toyota      19099   9553  20844  167169
# ...

# %%
novo_df = carros2[carros2 > 9000]
novo_df
# Out:
#                 jan      fev      mar      abr      mai      jun      jul  \
# fiat        17754.0  10392.0      NaN  19725.0  21176.0  23676.0      NaN
# peugeot     13286.0  13721.0  17330.0      NaN  23357.0  24485.0      NaN
# volkswagen      NaN  14035.0      NaN  21530.0  20752.0  20984.0  15145.0
# ford            NaN      NaN  13736.0  17491.0  21943.0      NaN  23361.0
# nissan          NaN      NaN  20002.0      NaN  17863.0  16167.0      NaN
# toyota          NaN      NaN  24098.0      NaN      NaN  24441.0  16298.0
# honda       14163.0  16442.0  17081.0  12293.0      NaN      NaN  20892.0
# chevrolet   14707.0  10466.0      NaN  11903.0      NaN  18851.0      NaN
#
#                 ago    set      out      nov    dez   total
# fiat            NaN   9073  15596.0  14827.0  16256  170439
# peugeot     17324.0  15413  15591.0      NaN  22601  184436
# volkswagen      NaN  12039      NaN  10479.0  13487  159800
# ford         9703.0  14314  12620.0  21972.0   9259  164502
# ...

# %%
#usando a função fillna a gentre troca os NAN por um numero
novo_df.fillna(0)
# Out:
#                 jan      fev      mar      abr      mai      jun      jul  \
# fiat        17754.0  10392.0      0.0  19725.0  21176.0  23676.0      0.0
# peugeot     13286.0  13721.0  17330.0      0.0  23357.0  24485.0      0.0
# volkswagen      0.0  14035.0      0.0  21530.0  20752.0  20984.0  15145.0
# ford            0.0      0.0  13736.0  17491.0  21943.0      0.0  23361.0
# nissan          0.0      0.0  20002.0      0.0  17863.0  16167.0      0.0
# toyota          0.0      0.0  24098.0      0.0      0.0  24441.0  16298.0
# honda       14163.0  16442.0  17081.0  12293.0      0.0      0.0  20892.0
# chevrolet   14707.0  10466.0      0.0  11903.0      0.0  18851.0      0.0
#
#                 ago    set      out      nov    dez   total
# fiat            0.0   9073  15596.0  14827.0  16256  170439
# peugeot     17324.0  15413  15591.0      0.0  22601  184436
# volkswagen      0.0  12039      0.0  10479.0  13487  159800
# ford         9703.0  14314  12620.0  21972.0   9259  164502
# ...

# %%
#só atribui a mesma funão a outra variavel para poder usar
drop_df = carros2[carros2 > 9000]
drop_df
# Out:
#                 jan      fev      mar      abr      mai      jun      jul  \
# fiat        17754.0  10392.0      NaN  19725.0  21176.0  23676.0      NaN
# peugeot     13286.0  13721.0  17330.0      NaN  23357.0  24485.0      NaN
# volkswagen      NaN  14035.0      NaN  21530.0  20752.0  20984.0  15145.0
# ford            NaN      NaN  13736.0  17491.0  21943.0      NaN  23361.0
# nissan          NaN      NaN  20002.0      NaN  17863.0  16167.0      NaN
# toyota          NaN      NaN  24098.0      NaN      NaN  24441.0  16298.0
# honda       14163.0  16442.0  17081.0  12293.0      NaN      NaN  20892.0
# chevrolet   14707.0  10466.0      NaN  11903.0      NaN  18851.0      NaN
#
#                 ago    set      out      nov    dez   total
# fiat            NaN   9073  15596.0  14827.0  16256  170439
# peugeot     17324.0  15413  15591.0      NaN  22601  184436
# volkswagen      NaN  12039      NaN  10479.0  13487  159800
# ford         9703.0  14314  12620.0  21972.0   9259  164502
# ...

# %%
#essa funão mostraria a linas que n tem valores NAM
drop_df.dropna()
# Out:
# Empty DataFrame
# Columns: [jan, fev, mar, abr, mai, jun, jul, ago, set, out, nov, dez, total]
# Index: []

# %%
#usando o axis=1 a gente faz uma varedura nas colunas que n contem NAM
drop_df.dropna(axis=1)
# Out:
#               set    dez   total
# fiat         9073  16256  170439
# peugeot     15413  22601  184436
# volkswagen  12039  13487  159800
# ford        14314   9259  164502
# nissan      15483  13537  147646
# toyota      24577  20844  167169
# honda       23684   9164  189071
# chevrolet   15198  10304  139894

# %%
#Usado para saber se têm valores nulos em forma de bool
drop_df.isnull()
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        False  False   True  False  False  False   True   True  False
# peugeot     False  False  False   True  False  False   True  False  False
# volkswagen   True  False   True  False  False  False  False   True  False
# ford         True   True  False  False  False   True  False  False  False
# nissan       True   True  False   True  False  False   True  False  False
# toyota       True   True  False   True   True  False  False  False  False
# honda       False  False  False  False   True   True  False  False  False
# chevrolet   False  False   True  False   True  False   True  False  False
#
#               out    nov    dez  total
# fiat        False  False  False  False
# peugeot     False   True  False  False
# volkswagen   True  False  False  False
# ford        False  False  False  False
# nissan      False  False  False  False
# toyota      False  False  False  False
# ...

# %%
carros
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#               out    nov    dez   total    origem
# fiat        15596  14827  16256  170439    italia
# peugeot     15591   8886  22601  184436    frança
# volkswagen   8967  10479  13487  159800  alemanha
# ford        12620  21972   9259  164502       eua
# ...

# %%
#pegando o mair numero da coluna março
carros[carros['mar'] == carros['mar'].max()]
# Out:
#          jan   fev    mar   abr   mai    jun    jul   ago    set    out   nov  \
# toyota  5845  5679  24098  3466  3456  24441  16298  9813  24577  19099  9553
#
#           dez   total origem
# toyota  20844  167169  japão

# %%
carros[carros['origem'] == 'japão'][['total', 'origem']]
# Out:
#          total origem
# nissan  147646  japão
# toyota  167169  japão
# honda   189071  japão

# %%
#se atentar as parenteses e cochetes
carros[(carros['origem'] == 'japão') & (carros['abr'] >= 11000)]
# Out:
#          jan    fev    mar    abr   mai   jun    jul    ago    set    out  \
# honda  14163  16442  17081  12293  8499  5905  20892  19064  23684  23813
#
#          nov   dez   total origem
# honda  18071  9164  189071  japão

# %%
carros['jan'].max()
# Out:
# np.int32(17754)

# %%
carros['jan'].min()
# Out:
# np.int32(4695)

# %%
#reseta o index 
aaa = carros.reset_index()
aaa
# Out:
#         index    jan    fev    mar    abr    mai    jun    jul    ago    set  \
# 0        fiat  17754  10392   7257  19725  21176  23676   8682   6025   9073
# 1     peugeot  13286  13721  17330   6416  23357  24485   6026  17324  15413
# 2  volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# 3        ford   8348   5245  13736  17491  21943   6510  23361   9703  14314
# 4      nissan   4695   8615  20002   4930  17863  16167   4030  15840  15483
# 5      toyota   5845   5679  24098   3466   3456  24441  16298   9813  24577
# 6       honda  14163  16442  17081  12293   8499   5905  20892  19064  23684
# 7   chevrolet  14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#      out    nov    dez   total    origem
# 0  15596  14827  16256  170439    italia
# 1  15591   8886  22601  184436    frança
# 2   8967  10479  13487  159800  alemanha
# 3  12620  21972   9259  164502       eua
# 4  11086  15398  13537  147646     japão
# ...

# %%
carrao=carros.copy()

# %%
carros.reset_index(drop=True,inplace=True)
carros
# Out:
#      jan    fev    mar    abr    mai    jun    jul    ago    set    out  \
# 0  17754  10392   7257  19725  21176  23676   8682   6025   9073  15596
# 1  13286  13721  17330   6416  23357  24485   6026  17324  15413  15591
# 2   7285  14035   8234  21530  20752  20984  15145   6863  12039   8967
# 3   8348   5245  13736  17491  21943   6510  23361   9703  14314  12620
# 4   4695   8615  20002   4930  17863  16167   4030  15840  15483  11086
# 5   5845   5679  24098   3466   3456  24441  16298   9813  24577  19099
# 6  14163  16442  17081  12293   8499   5905  20892  19064  23684  23813
# 7  14707  10466   7400  11903   4635  18851   3925  19863  15198   5021
#
#      nov    dez   total    origem
# 0  14827  16256  170439    italia
# 1   8886  22601  184436    frança
# 2  10479  13487  159800  alemanha
# 3  21972   9259  164502       eua
# 4  15398  13537  147646     japão
# 5   9553  20844  167169     japão
# 6  18071   9164  189071     japão
# 7  17621  10304  139894       eua

# %%
carros['novos_carros'] = ['fiat', 'peugeot', 'volkswagen', 'ford', 'nissan', 'toyota', 'honda', 'chevrolet']

# %%
carros
# Out:
#      jan    fev    mar    abr    mai    jun    jul    ago    set    out  \
# 0  17754  10392   7257  19725  21176  23676   8682   6025   9073  15596
# 1  13286  13721  17330   6416  23357  24485   6026  17324  15413  15591
# 2   7285  14035   8234  21530  20752  20984  15145   6863  12039   8967
# 3   8348   5245  13736  17491  21943   6510  23361   9703  14314  12620
# 4   4695   8615  20002   4930  17863  16167   4030  15840  15483  11086
# 5   5845   5679  24098   3466   3456  24441  16298   9813  24577  19099
# 6  14163  16442  17081  12293   8499   5905  20892  19064  23684  23813
# 7  14707  10466   7400  11903   4635  18851   3925  19863  15198   5021
#
#      nov    dez   total    origem novos_carros
# 0  14827  16256  170439    italia         fiat
# 1   8886  22601  184436    frança      peugeot
# 2  10479  13487  159800  alemanha   volkswagen
# 3  21972   9259  164502       eua         ford
# 4  15398  13537  147646     japão       nissan
# ...

# %%
#trasformar uma coluna em index com set.index
carros.set_index('novos_carros', inplace=True)

# %%
carros
# Out:
#                 jan    fev    mar    abr    mai    jun    jul    ago    set  \
# novos_carros
# fiat          17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot       13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen     7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford           8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan         4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota         5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda         14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet     14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#                 out    nov    dez   total    origem
# novos_carros
# fiat          15596  14827  16256  170439    italia
# peugeot       15591   8886  22601  184436    frança
# volkswagen     8967  10479  13487  159800  alemanha
# ...

# %%
agrupando = carros.groupby(['origem'])
agrupando

# %%
#vendo a descrição usando o describe
agrupando.describe()
# Out:
#            jan                                                         \
#          count          mean          std      min       25%      50%
# origem
# alemanha   1.0   7285.000000          NaN   7285.0   7285.00   7285.0
# eua        2.0  11527.500000  4496.492022   8348.0   9937.75  11527.5
# frança     1.0  13286.000000          NaN  13286.0  13286.00  13286.0
# italia     1.0  17754.000000          NaN  17754.0  17754.00  17754.0
# japão      3.0   8234.333333  5166.472814   4695.0   5270.00   5845.0
#
#                               fev                ...       dez          total  \
#                75%      max count          mean  ...       75%      max count
# origem                                           ...
# alemanha   7285.00   7285.0   1.0  14035.000000  ...  13487.00  13487.0   1.0
# eua       13117.25  14707.0   2.0   7855.500000  ...  10042.75  10304.0   2.0
# frança    13286.00  13286.0   1.0  13721.000000  ...  22601.00  22601.0   1.0
# ...

# %%
# usando o T para mudar a transposição no caso oq é coluna vira linha e visce verso
agrupando.describe().T.head(30)
# Out:
# origem     alemanha           eua   frança   italia         japão
# jan count       1.0      2.000000      1.0      1.0      3.000000
#     mean     7285.0  11527.500000  13286.0  17754.0   8234.333333
#     std         NaN   4496.492022      NaN      NaN   5166.472814
#     min      7285.0   8348.000000  13286.0  17754.0   4695.000000
#     25%      7285.0   9937.750000  13286.0  17754.0   5270.000000
#     50%      7285.0  11527.500000  13286.0  17754.0   5845.000000
#     75%      7285.0  13117.250000  13286.0  17754.0  10004.000000
#     max      7285.0  14707.000000  13286.0  17754.0  14163.000000
# fev count       1.0      2.000000      1.0      1.0      3.000000
#     mean    14035.0   7855.500000  13721.0  10392.0  10245.333333
#     std         NaN   3691.804505      NaN      NaN   5563.634813
#     min     14035.0   5245.000000  13721.0  10392.0   5679.000000
#     25%     14035.0   6550.250000  13721.0  10392.0   7147.000000
# ...

# %%
agrupando.max()
# Out:
#             jan    fev    mar    abr    mai    jun    jul    ago    set  \
# origem
# alemanha   7285  14035   8234  21530  20752  20984  15145   6863  12039
# eua       14707  10466  13736  17491  21943  18851  23361  19863  15198
# frança    13286  13721  17330   6416  23357  24485   6026  17324  15413
# italia    17754  10392   7257  19725  21176  23676   8682   6025   9073
# japão     14163  16442  24098  12293  17863  24441  20892  19064  24577
#
#             out    nov    dez   total
# origem
# alemanha   8967  10479  13487  159800
# eua       12620  21972  10304  164502
# frança    15591   8886  22601  184436
# italia    15596  14827  16256  170439
# japão     23813  18071  20844  189071

# %%
agrupando.min()
# Out:
#             jan    fev    mar    abr    mai    jun    jul    ago    set  \
# origem
# alemanha   7285  14035   8234  21530  20752  20984  15145   6863  12039
# eua        8348   5245   7400  11903   4635   6510   3925   9703  14314
# frança    13286  13721  17330   6416  23357  24485   6026  17324  15413
# italia    17754  10392   7257  19725  21176  23676   8682   6025   9073
# japão      4695   5679  17081   3466   3456   5905   4030   9813  15483
#
#             out    nov    dez   total
# origem
# alemanha   8967  10479  13487  159800
# eua        5021  17621   9259  139894
# frança    15591   8886  22601  184436
# italia    15596  14827  16256  170439
# japão     11086   9553   9164  147646

# %%
acidentes = pd.DataFrame(np.random.randint(50,200, size= (7,12) ),
index=['fiat', 'peugeot', 'volkswagen', 'ford', 'nissan', 'toyota', 'honda'],
columns=['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out',
       'nov', 'dez'])

# %%
acidentes
# Out:
#             jan  fev  mar  abr  mai  jun  jul  ago  set  out  nov  dez
# fiat        103   69  130  113  162  105  173   93  111  178  113  116
# peugeot     188  191  192  189   89  176  179  178  158  124  147  164
# volkswagen  148  182  194  146  124  189  161  110  144  190   62  161
# ford         78  146  189  171  124  163  100  153  114   98   82  112
# nissan      184  107  147  107  177  116  186   52  147  156  123  111
# toyota       51  199  179  174   70   96   76   70   50   90  130   81
# honda        95   84  193  117  190   70  144   56  189   77  175  195

# %%
acidentes['total'] = acidentes.sum(axis=1)
acidentes
# Out:
#             jan  fev  mar  abr  mai  jun  jul  ago  set  out  nov  dez  total
# fiat        103   69  130  113  162  105  173   93  111  178  113  116   1466
# peugeot     188  191  192  189   89  176  179  178  158  124  147  164   1975
# volkswagen  148  182  194  146  124  189  161  110  144  190   62  161   1811
# ford         78  146  189  171  124  163  100  153  114   98   82  112   1530
# nissan      184  107  147  107  177  116  186   52  147  156  123  111   1613
# toyota       51  199  179  174   70   96   76   70   50   90  130   81   1266
# honda        95   84  193  117  190   70  144   56  189   77  175  195   1585

# %%
pd.concat([carros, acidentes] , axis=1).T
# Out:
#           fiat peugeot volkswagen    ford  nissan  toyota   honda chevrolet
# jan      17754   13286       7285    8348    4695    5845   14163     14707
# fev      10392   13721      14035    5245    8615    5679   16442     10466
# mar       7257   17330       8234   13736   20002   24098   17081      7400
# abr      19725    6416      21530   17491    4930    3466   12293     11903
# mai      21176   23357      20752   21943   17863    3456    8499      4635
# jun      23676   24485      20984    6510   16167   24441    5905     18851
# jul       8682    6026      15145   23361    4030   16298   20892      3925
# ago       6025   17324       6863    9703   15840    9813   19064     19863
# set       9073   15413      12039   14314   15483   24577   23684     15198
# out      15596   15591       8967   12620   11086   19099   23813      5021
# nov      14827    8886      10479   21972   15398    9553   18071     17621
# ...

# %%
carros
# Out:
#                 jan    fev    mar    abr    mai    jun    jul    ago    set  \
# novos_carros
# fiat          17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot       13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen     7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford           8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan         4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota         5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda         14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet     14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#                 out    nov    dez   total    origem
# novos_carros
# fiat          15596  14827  16256  170439    italia
# peugeot       15591   8886  22601  184436    frança
# volkswagen     8967  10479  13487  159800  alemanha
# ...

# %%
carrao
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
#
#               out    nov    dez   total    origem
# fiat        15596  14827  16256  170439    italia
# peugeot     15591   8886  22601  184436    frança
# volkswagen   8967  10479  13487  159800  alemanha
# ford        12620  21972   9259  164502       eua
# ...

# %%
carros_conpleto = pd.concat([carros, carrao])
carros_conpleto
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# ...

# %%
carros_conpleto['sigla list comprehensions'] = [l[:3].upper() for l in carros_conpleto['origem']] 
carros_conpleto
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# ...

# %%
carros_conpleto['sigla lambda'] = carros_conpleto['origem'].apply(lambda x : x[:3].upper())
carros_conpleto
# Out:
#               jan    fev    mar    abr    mai    jun    jul    ago    set  \
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# nissan       4695   8615  20002   4930  17863  16167   4030  15840  15483
# toyota       5845   5679  24098   3466   3456  24441  16298   9813  24577
# honda       14163  16442  17081  12293   8499   5905  20892  19064  23684
# chevrolet   14707  10466   7400  11903   4635  18851   3925  19863  15198
# fiat        17754  10392   7257  19725  21176  23676   8682   6025   9073
# peugeot     13286  13721  17330   6416  23357  24485   6026  17324  15413
# volkswagen   7285  14035   8234  21530  20752  20984  15145   6863  12039
# ford         8348   5245  13736  17491  21943   6510  23361   9703  14314
# ...

# %%
carros3 = carros_conpleto.copy()

# %% [markdown]
# Matplotlib

# %%
'''ros3.drop('total', axis=1, inplace=True
carros3'''
# Out:
# "ros3.drop('total', axis=1, inplace=True\ncarros3"

# %%
carros4 = carros3.T
carros4
# Out:
#                              fiat peugeot volkswagen    ford  nissan  toyota  \
# jan                         17754   13286       7285    8348    4695    5845
# fev                         10392   13721      14035    5245    8615    5679
# mar                          7257   17330       8234   13736   20002   24098
# abr                         19725    6416      21530   17491    4930    3466
# mai                         21176   23357      20752   21943   17863    3456
# jun                         23676   24485      20984    6510   16167   24441
# jul                          8682    6026      15145   23361    4030   16298
# ago                          6025   17324       6863    9703   15840    9813
# set                          9073   15413      12039   14314   15483   24577
# out                         15596   15591       8967   12620   11086   19099
# nov                         14827    8886      10479   21972   15398    9553
# ...

# %%
carros4.drop(['total'], inplace=True)
carros4.drop(['sigla lambda'], inplace=True)
carros4.drop(['sigla list comprehensions'], inplace=True)
carros4.drop(['origem'], inplace=True)

# %%
carros4
# Out:
#       fiat peugeot volkswagen   ford nissan toyota  honda chevrolet   fiat  \
# jan  17754   13286       7285   8348   4695   5845  14163     14707  17754
# fev  10392   13721      14035   5245   8615   5679  16442     10466  10392
# mar   7257   17330       8234  13736  20002  24098  17081      7400   7257
# abr  19725    6416      21530  17491   4930   3466  12293     11903  19725
# mai  21176   23357      20752  21943  17863   3456   8499      4635  21176
# jun  23676   24485      20984   6510  16167  24441   5905     18851  23676
# jul   8682    6026      15145  23361   4030  16298  20892      3925   8682
# ago   6025   17324       6863   9703  15840   9813  19064     19863   6025
# set   9073   15413      12039  14314  15483  24577  23684     15198   9073
# out  15596   15591       8967  12620  11086  19099  23813      5021  15596
# nov  14827    8886      10479  21972  15398   9553  18071     17621  14827
# ...

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')

# %%
plt.plot(carros4['fiat'], color = 'red')
plt.title('Vendas:Fiat' , fontsize = 20)
plt.xlabel('Meses', fontsize = 16)
plt.ylabel('Quantidade vendida' , fontsize = 16)
# Out:
# Text(0, 0.5, 'Quantidade vendida')

# %%
plt.figure(figsize=(12, 5))  # Define o tamanho da figura

# Primeiro gráfico
plt.subplot(1, 2, 1)  # 1 linha, 2 colunas, posição 1
plt.plot(carros4['volkswagen'], color='blue', label='Volkswagen')
plt.xticks(rotation=90)
plt.title('Volkswagen')
plt.legend()

# Segundo gráfico
plt.subplot(1, 2, 2)  # 1 linha, 2 colunas, posição 2
plt.plot(carros4['ford'], color='red', label='Ford')
plt.xticks(rotation=90)
plt.title('Ford')
plt.legend()

plt.tight_layout()  # Ajusta o layout para evitar sobreposição
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(carros4['peugeot'], color = 'orange', linestyle = '--', linewidth= 3, alpha = 0.7, marker = '^', markersize = '15',
       markerfacecolor ='red' , markeredgecolor = 'black', markeredgewidth = 2, label ='peugeot')
ax.plot(carros4['honda'], color = 'navy',linestyle = 'dashdot', linewidth = 3, label = 'honda')
ax.set_title('Comparativo de peugeot com honda', fontsize= 20)
ax.set_xlabel('Meses', fontsize = 16)
ax.set_ylabel('Quantidade vendida', fontsize = 16)
ax.legend()

####################################

ax = fig.add_axes([0.2,0.1,0.3,0.3])
ax.plot(carros4['peugeot'], color = 'orange', linestyle = '--', linewidth= 3, alpha = 0.7, marker = '^', markersize = '15',
       markerfacecolor ='red' , markeredgecolor = 'black', markeredgewidth = 2, label ='peugeot')
ax.plot(carros4['honda'], color = 'navy',linestyle = 'dashdot', linewidth = 3, label = 'honda')

ax.set_xlim(['mai', 'set'])
ax.set_ylim([11500, 22500])

ax.set_xlabel('Meses', fontsize = 16)
ax.set_ylabel('Quantidade vendida', fontsize = 16)
# Out:
# Text(0, 0.5, 'Quantidade vendida')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(carros4['peugeot'], color = 'orange', linestyle = '--', linewidth= 3, alpha = 0.7, marker = '^', markersize = '15',
       markerfacecolor ='red' , markeredgecolor = 'black', markeredgewidth = 2, label ='peugeot')
ax.plot(carros4['honda'], color = 'navy',linestyle = 'dashdot', linewidth = 3, label = 'honda')

ax.set_xlim(['mai', 'set'])
ax.set_ylim([11500, 22500])

ax.set_title('Comparativo de peugeot com honda', fontsize= 20)
ax.set_xlabel('Meses', fontsize = 16)
ax.set_ylabel('Quantidade vendida', fontsize = 16)
ax.legend()

# %%
quant = [  8678, 3765, 9076, 3240,5640, 2345, 2356,5747 ]
preco = [ 200000, 17000, 130000, 1080000, 91000, 85000, 81235, 75444]

fig, ax = plt.subplots(figsize = (10,6))
ax.scatter(quant,preco)

ax.set_title('Comparativo', fontsize= 20)
ax.set_xlabel('Quantidade', fontsize = 20)
ax.set_ylabel('preo(R$)', fontsize = 20)
# Out:
# Text(0, 0.5, 'preo(R$)')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

ax[0].scatter(quant, preco)
ax[0].set_title('Scatter', fontsize = 18)

ax[1].scatter(quant, preco)
ax[1].set_title('Linha', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Linha')

# %%
carros4.columns
# Out:
# Index(['fiat', 'peugeot', 'volkswagen', 'ford', 'nissan', 'toyota', 'honda',
#        'chevrolet', 'fiat', 'peugeot', 'volkswagen', 'ford', 'nissan',
#        'toyota', 'honda', 'chevrolet'],
#       dtype='object')

# %%
carros4[['fiat', 'peugeot', 'volkswagen', 'ford', 'nissan', 'toyota', 'honda',
       'chevrolet', 'fiat', 'peugeot', 'volkswagen', 'ford', 'nissan',
       'toyota', 'honda', 'chevrolet']].plot(kind= 'bar', subplots = True, figsize = (15, 50))
plt.show()

# %%
x = np.random.randn(10000)
fig, ax =plt.subplots()
ax.hist(x, bins = 30)
ax.set_title('Histograma', fontsize = 18)
plt.show()
